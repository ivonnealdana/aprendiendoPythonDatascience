# %%
import urllib

# %%
params = 'DRIVER={ODBC Driver 17 for SQL Server};' \
         'SERVER=tcp:pythondatasciencesrv.database.windows.net;' \
         'PORT=1433;' \
         'DATABASE=pythondatascienceTestDB;' \
         'UID=azureuser;' \
         'PWD=pythonRocks!;'
params = urllib.parse.quote_plus(params)

# %%
from sqlalchemy import create_engine
db = create_engine('mssql+pyodbc:///?odbc_connect=%s' % params)

# %%
import pandas as pd
sql = 'SELECT * FROM [SalesLT].[SalesOrderHeader]'
df = pd.read_sql_query(sql, db)

# %%
df.columns
# Out:
# Index(['SalesOrderID', 'RevisionNumber', 'OrderDate', 'DueDate', 'ShipDate',
#        'Status', 'OnlineOrderFlag', 'SalesOrderNumber', 'PurchaseOrderNumber',
#        'AccountNumber', 'CustomerID', 'ShipToAddressID', 'BillToAddressID',
#        'ShipMethod', 'CreditCardApprovalCode', 'SubTotal', 'TaxAmt', 'Freight',
#        'TotalDue', 'Comment', 'rowguid', 'ModifiedDate'],
#       dtype='object')

# %%
df.axes
# Out:
# [RangeIndex(start=0, stop=32, step=1),
#  Index(['SalesOrderID', 'RevisionNumber', 'OrderDate', 'DueDate', 'ShipDate',
#         'Status', 'OnlineOrderFlag', 'SalesOrderNumber', 'PurchaseOrderNumber',
#         'AccountNumber', 'CustomerID', 'ShipToAddressID', 'BillToAddressID',
#         'ShipMethod', 'CreditCardApprovalCode', 'SubTotal', 'TaxAmt', 'Freight',
#         'TotalDue', 'Comment', 'rowguid', 'ModifiedDate'],
#        dtype='object')]

# %%
df.ndim
# Out:
# 2

# %%
df.size
# Out:
# 704

# %%
df.values
# Out:
# array([[71774, 2, Timestamp('2008-06-01 00:00:00'),
#         Timestamp('2008-06-13 00:00:00'),
#         Timestamp('2008-06-08 00:00:00'), 5, False, 'SO71774',
#         'PO348186287', '10-4020-000609', 29847, 1092, 1092,
#         'CARGO TRANSPORT 5', None, 880.3484, 70.4279, 22.0087, 972.785,
#         None, '89E42CDC-8506-48A2-B89B-EB3E64E3554E',
#         Timestamp('2008-06-08 00:00:00')],
#        [71776, 2, Timestamp('2008-06-01 00:00:00'),
#         Timestamp('2008-06-13 00:00:00'),
#         Timestamp('2008-06-08 00:00:00'), 5, False, 'SO71776',
#         'PO19952192051', '10-4020-000106', 30072, 640, 640,
#         'CARGO TRANSPORT 5', None, 78.81, 6.3048, 1.9703, 87.0851, None,
#         '8A3448C5-E677-4158-A29B-DD33069BE0B0',
#         Timestamp('2008-06-08 00:00:00')],
#        [71780, 2, Timestamp('2008-06-01 00:00:00'),
#         Timestamp('2008-06-13 00:00:00'),
#         Timestamp('2008-06-08 00:00:00'), 5, False, 'SO71780',
# ...

# %%
df.describe
# Out:
# <bound method NDFrame.describe of     SalesOrderID  RevisionNumber  OrderDate    DueDate   ShipDate  Status  \
# 0          71774               2 2008-06-01 2008-06-13 2008-06-08       5
# 1          71776               2 2008-06-01 2008-06-13 2008-06-08       5
# 2          71780               2 2008-06-01 2008-06-13 2008-06-08       5
# 3          71782               2 2008-06-01 2008-06-13 2008-06-08       5
# 4          71783               2 2008-06-01 2008-06-13 2008-06-08       5
# 5          71784               2 2008-06-01 2008-06-13 2008-06-08       5
# 6          71796               2 2008-06-01 2008-06-13 2008-06-08       5
# 7          71797               2 2008-06-01 2008-06-13 2008-06-08       5
# 8          71815               2 2008-06-01 2008-06-13 2008-06-08       5
# 9          71816               2 2008-06-01 2008-06-13 2008-06-08       5
# 10         71831               2 2008-06-01 2008-06-13 2008-06-08       5
# ...
